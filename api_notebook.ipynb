# %% [markdown]
# # APIs and Python

# %% [markdown]
# ## The Many Use Cases for APIs
# APIs can actually be used for many things - not just for retrieving information. Twilio has an API that allows you to write a script to call their API to send text messages to people. GitHub has an API for creating new repositories. Many services have an API allowing a computer to automate a task that a person might otherwise have to do through a website - whether uploading a photo to Flickr, searching for a company name in a state database or getting a list of garbage collection times for a municipality.
#
#
# ## Limitations of APIs
# When working with APIs, there are some limitations you have to be aware of - especially relating to scope and scale.
# * **Scope** - Just because a company has an API and has information, it doesn't mean you can get all of the information through their API. Any time you want to get information from a given API, write a small test script and make sure it actually allows you to access the things you need in the way you require.
# * **Scale** - Some APIs are provided for free as a public service. Others you have to pay for, or allow you to perform activities (like sending a text message) that you pay for. Whatever the commercial model, all APIs have some kind of rate limiting. Because it costs money to keep computers running and because you could write a script to ask lots and lots of questions of an API, generally an API will have some kind of limitations on the number of "API calls" you can make against the service per unit of time. Make sure that you know what the rate limits are and that your use case isn't going to need more API calls than you will be able to make.
#
# Let's take a look at the requests library and it's uses.

# %%
# !pip install requests
import requests

# %% [markdown]
# ### GET versus POST

# %%
#create a GET request from https://api.github.com/events and view it in json format

r = requests.get("https://api.github.com/events") #put url here!
r.json()
# Out:
# [{'id': '9624211531',
#   'type': 'PullRequestEvent',
#   'actor': {'id': 2270752,
#    'login': 'vero4karu',
#    'display_login': 'vero4karu',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/vero4karu',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/2270752?'},
#   'repo': {'id': 83940669,
#    'name': 'vero4karu/desparchado',
#    'url': 'https://api.github.com/repos/vero4karu/desparchado'},
#   'payload': {'action': 'opened',
#    'number': 85,
#    'pull_request': {'url': 'https://api.github.com/repos/vero4karu/desparchado/pulls/85',
#     'id': 278762067,
#     'node_id': 'MDExOlB1bGxSZXF1ZXN0Mjc4NzYyMDY3',
#     'html_url': 'https://github.com/vero4karu/desparchado/pull/85',
#     'diff_url': 'https://github.com/vero4karu/desparchado/pull/85.diff',
#     'patch_url': 'https://github.com/vero4karu/desparchado/pull/85.patch',
#     'issue_url': 'https://api.github.com/repos/vero4karu/desparchado/issues/85',
#     'number': 85,
#     'state': 'open',
#     'locked': False,
#     'title': 'Remove link to FILBO special',
#     'user': {'login': 'vero4karu',
#      'id': 2270752,
#      'node_id': 'MDQ6VXNlcjIyNzA3NTI=',
#      'avatar_url': 'https://avatars3.githubusercontent.com/u/2270752?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/vero4karu',
#      'html_url': 'https://github.com/vero4karu',
#      'followers_url': 'https://api.github.com/users/vero4karu/followers',
#      'following_url': 'https://api.github.com/users/vero4karu/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/vero4karu/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/vero4karu/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/vero4karu/subscriptions',
#      'organizations_url': 'https://api.github.com/users/vero4karu/orgs',
#      'repos_url': 'https://api.github.com/users/vero4karu/repos',
#      'events_url': 'https://api.github.com/users/vero4karu/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/vero4karu/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'body': '',
#     'created_at': '2019-05-14T16:33:33Z',
#     'updated_at': '2019-05-14T16:33:33Z',
#     'closed_at': None,
#     'merged_at': None,
#     'merge_commit_sha': None,
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [],
#     'requested_teams': [],
#     'labels': [],
#     'milestone': None,
#     'commits_url': 'https://api.github.com/repos/vero4karu/desparchado/pulls/85/commits',
#     'review_comments_url': 'https://api.github.com/repos/vero4karu/desparchado/pulls/85/comments',
#     'review_comment_url': 'https://api.github.com/repos/vero4karu/desparchado/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/vero4karu/desparchado/issues/85/comments',
#     'statuses_url': 'https://api.github.com/repos/vero4karu/desparchado/statuses/ddc9af550d95abc1f53357727b808b5a0c36e3e7',
#     'head': {'label': 'vero4karu:development',
#      'ref': 'development',
#      'sha': 'ddc9af550d95abc1f53357727b808b5a0c36e3e7',
#      'user': {'login': 'vero4karu',
#       'id': 2270752,
#       'node_id': 'MDQ6VXNlcjIyNzA3NTI=',
#       'avatar_url': 'https://avatars3.githubusercontent.com/u/2270752?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/vero4karu',
#       'html_url': 'https://github.com/vero4karu',
#       'followers_url': 'https://api.github.com/users/vero4karu/followers',
#       'following_url': 'https://api.github.com/users/vero4karu/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/vero4karu/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/vero4karu/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/vero4karu/subscriptions',
#       'organizations_url': 'https://api.github.com/users/vero4karu/orgs',
#       'repos_url': 'https://api.github.com/users/vero4karu/repos',
#       'events_url': 'https://api.github.com/users/vero4karu/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/vero4karu/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 83940669,
#       'node_id': 'MDEwOlJlcG9zaXRvcnk4Mzk0MDY2OQ==',
#       'name': 'desparchado',
#       'full_name': 'vero4karu/desparchado',
#       'private': False,
#       'owner': {'login': 'vero4karu',
#        'id': 2270752,
#        'node_id': 'MDQ6VXNlcjIyNzA3NTI=',
#        'avatar_url': 'https://avatars3.githubusercontent.com/u/2270752?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/vero4karu',
#        'html_url': 'https://github.com/vero4karu',
#        'followers_url': 'https://api.github.com/users/vero4karu/followers',
#        'following_url': 'https://api.github.com/users/vero4karu/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/vero4karu/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/vero4karu/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/vero4karu/subscriptions',
#        'organizations_url': 'https://api.github.com/users/vero4karu/orgs',
#        'repos_url': 'https://api.github.com/users/vero4karu/repos',
#        'events_url': 'https://api.github.com/users/vero4karu/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/vero4karu/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/vero4karu/desparchado',
#       'description': 'Events in Colombia',
#       'fork': False,
#       'url': 'https://api.github.com/repos/vero4karu/desparchado',
#       'forks_url': 'https://api.github.com/repos/vero4karu/desparchado/forks',
#       'keys_url': 'https://api.github.com/repos/vero4karu/desparchado/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/vero4karu/desparchado/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/vero4karu/desparchado/teams',
#       'hooks_url': 'https://api.github.com/repos/vero4karu/desparchado/hooks',
#       'issue_events_url': 'https://api.github.com/repos/vero4karu/desparchado/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/vero4karu/desparchado/events',
#       'assignees_url': 'https://api.github.com/repos/vero4karu/desparchado/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/vero4karu/desparchado/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/vero4karu/desparchado/tags',
#       'blobs_url': 'https://api.github.com/repos/vero4karu/desparchado/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/vero4karu/desparchado/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/vero4karu/desparchado/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/vero4karu/desparchado/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/vero4karu/desparchado/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/vero4karu/desparchado/languages',
#       'stargazers_url': 'https://api.github.com/repos/vero4karu/desparchado/stargazers',
#       'contributors_url': 'https://api.github.com/repos/vero4karu/desparchado/contributors',
#       'subscribers_url': 'https://api.github.com/repos/vero4karu/desparchado/subscribers',
#       'subscription_url': 'https://api.github.com/repos/vero4karu/desparchado/subscription',
#       'commits_url': 'https://api.github.com/repos/vero4karu/desparchado/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/vero4karu/desparchado/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/vero4karu/desparchado/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/vero4karu/desparchado/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/vero4karu/desparchado/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/vero4karu/desparchado/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/vero4karu/desparchado/merges',
#       'archive_url': 'https://api.github.com/repos/vero4karu/desparchado/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/vero4karu/desparchado/downloads',
#       'issues_url': 'https://api.github.com/repos/vero4karu/desparchado/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/vero4karu/desparchado/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/vero4karu/desparchado/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/vero4karu/desparchado/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/vero4karu/desparchado/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/vero4karu/desparchado/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/vero4karu/desparchado/deployments',
#       'created_at': '2017-03-05T03:04:59Z',
#       'updated_at': '2019-04-28T18:18:10Z',
#       'pushed_at': '2019-05-14T16:33:15Z',
#       'git_url': 'git://github.com/vero4karu/desparchado.git',
#       'ssh_url': 'git@github.com:vero4karu/desparchado.git',
#       'clone_url': 'https://github.com/vero4karu/desparchado.git',
#       'svn_url': 'https://github.com/vero4karu/desparchado',
#       'homepage': 'http://desparchado.co/',
#       'size': 4877,
#       'stargazers_count': 2,
#       'watchers_count': 2,
#       'language': 'CSS',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 1,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 14,
#       'license': None,
#       'forks': 1,
#       'open_issues': 14,
#       'watchers': 2,
#       'default_branch': 'master'}},
#     'base': {'label': 'vero4karu:master',
#      'ref': 'master',
#      'sha': '95068a219ab5a1feb1095f7c9a53d5295d0ec984',
#      'user': {'login': 'vero4karu',
#       'id': 2270752,
#       'node_id': 'MDQ6VXNlcjIyNzA3NTI=',
#       'avatar_url': 'https://avatars3.githubusercontent.com/u/2270752?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/vero4karu',
#       'html_url': 'https://github.com/vero4karu',
#       'followers_url': 'https://api.github.com/users/vero4karu/followers',
#       'following_url': 'https://api.github.com/users/vero4karu/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/vero4karu/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/vero4karu/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/vero4karu/subscriptions',
#       'organizations_url': 'https://api.github.com/users/vero4karu/orgs',
#       'repos_url': 'https://api.github.com/users/vero4karu/repos',
#       'events_url': 'https://api.github.com/users/vero4karu/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/vero4karu/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 83940669,
#       'node_id': 'MDEwOlJlcG9zaXRvcnk4Mzk0MDY2OQ==',
#       'name': 'desparchado',
#       'full_name': 'vero4karu/desparchado',
#       'private': False,
#       'owner': {'login': 'vero4karu',
#        'id': 2270752,
#        'node_id': 'MDQ6VXNlcjIyNzA3NTI=',
#        'avatar_url': 'https://avatars3.githubusercontent.com/u/2270752?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/vero4karu',
#        'html_url': 'https://github.com/vero4karu',
#        'followers_url': 'https://api.github.com/users/vero4karu/followers',
#        'following_url': 'https://api.github.com/users/vero4karu/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/vero4karu/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/vero4karu/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/vero4karu/subscriptions',
#        'organizations_url': 'https://api.github.com/users/vero4karu/orgs',
#        'repos_url': 'https://api.github.com/users/vero4karu/repos',
#        'events_url': 'https://api.github.com/users/vero4karu/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/vero4karu/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/vero4karu/desparchado',
#       'description': 'Events in Colombia',
#       'fork': False,
#       'url': 'https://api.github.com/repos/vero4karu/desparchado',
#       'forks_url': 'https://api.github.com/repos/vero4karu/desparchado/forks',
#       'keys_url': 'https://api.github.com/repos/vero4karu/desparchado/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/vero4karu/desparchado/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/vero4karu/desparchado/teams',
#       'hooks_url': 'https://api.github.com/repos/vero4karu/desparchado/hooks',
#       'issue_events_url': 'https://api.github.com/repos/vero4karu/desparchado/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/vero4karu/desparchado/events',
#       'assignees_url': 'https://api.github.com/repos/vero4karu/desparchado/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/vero4karu/desparchado/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/vero4karu/desparchado/tags',
#       'blobs_url': 'https://api.github.com/repos/vero4karu/desparchado/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/vero4karu/desparchado/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/vero4karu/desparchado/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/vero4karu/desparchado/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/vero4karu/desparchado/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/vero4karu/desparchado/languages',
#       'stargazers_url': 'https://api.github.com/repos/vero4karu/desparchado/stargazers',
#       'contributors_url': 'https://api.github.com/repos/vero4karu/desparchado/contributors',
#       'subscribers_url': 'https://api.github.com/repos/vero4karu/desparchado/subscribers',
#       'subscription_url': 'https://api.github.com/repos/vero4karu/desparchado/subscription',
#       'commits_url': 'https://api.github.com/repos/vero4karu/desparchado/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/vero4karu/desparchado/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/vero4karu/desparchado/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/vero4karu/desparchado/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/vero4karu/desparchado/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/vero4karu/desparchado/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/vero4karu/desparchado/merges',
#       'archive_url': 'https://api.github.com/repos/vero4karu/desparchado/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/vero4karu/desparchado/downloads',
#       'issues_url': 'https://api.github.com/repos/vero4karu/desparchado/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/vero4karu/desparchado/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/vero4karu/desparchado/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/vero4karu/desparchado/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/vero4karu/desparchado/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/vero4karu/desparchado/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/vero4karu/desparchado/deployments',
#       'created_at': '2017-03-05T03:04:59Z',
#       'updated_at': '2019-04-28T18:18:10Z',
#       'pushed_at': '2019-05-14T16:33:15Z',
#       'git_url': 'git://github.com/vero4karu/desparchado.git',
#       'ssh_url': 'git@github.com:vero4karu/desparchado.git',
#       'clone_url': 'https://github.com/vero4karu/desparchado.git',
#       'svn_url': 'https://github.com/vero4karu/desparchado',
#       'homepage': 'http://desparchado.co/',
#       'size': 4877,
#       'stargazers_count': 2,
#       'watchers_count': 2,
#       'language': 'CSS',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 1,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 14,
#       'license': None,
#       'forks': 1,
#       'open_issues': 14,
#       'watchers': 2,
#       'default_branch': 'master'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/vero4karu/desparchado/pulls/85'},
#      'html': {'href': 'https://github.com/vero4karu/desparchado/pull/85'},
#      'issue': {'href': 'https://api.github.com/repos/vero4karu/desparchado/issues/85'},
#      'comments': {'href': 'https://api.github.com/repos/vero4karu/desparchado/issues/85/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/vero4karu/desparchado/pulls/85/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/vero4karu/desparchado/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/vero4karu/desparchado/pulls/85/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/vero4karu/desparchado/statuses/ddc9af550d95abc1f53357727b808b5a0c36e3e7'}},
#     'author_association': 'OWNER',
#     'merged': False,
#     'mergeable': None,
#     'rebaseable': None,
#     'mergeable_state': 'unknown',
#     'merged_by': None,
#     'comments': 0,
#     'review_comments': 0,
#     'maintainer_can_modify': False,
#     'commits': 1,
#     'additions': 0,
#     'deletions': 1,
#     'changed_files': 1}},
#   'public': True,
#   'created_at': '2019-05-14T16:33:33Z'},
#  {'id': '9624211523',
#   'type': 'CreateEvent',
#   'actor': {'id': 49867635,
#    'login': 'bakerynhom1',
#    'display_login': 'bakerynhom1',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/bakerynhom1',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/49867635?'},
#   'repo': {'id': 186661209,
#    'name': 'bakerynhom1/cartoon.io',
#    'url': 'https://api.github.com/repos/bakerynhom1/cartoon.io'},
#   'payload': {'ref': None,
#    'ref_type': 'repository',
#    'master_branch': 'master',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2019-05-14T16:33:33Z'},
#  {'id': '9624211506',
#   'type': 'PushEvent',
#   'actor': {'id': 43463633,
#    'login': 'neverland251',
#    'display_login': 'neverland251',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/neverland251',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/43463633?'},
#   'repo': {'id': 161427021,
#    'name': 'neverland251/MainProject',
#    'url': 'https://api.github.com/repos/neverland251/MainProject'},
#   'payload': {'push_id': 3607745322,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'cdf4474ac097a7c8b5fce1590d739671057595aa',
#    'before': '63228dbb7dead4e8c69c7eef61731f592649e001',
#    'commits': [{'sha': 'cdf4474ac097a7c8b5fce1590d739671057595aa',
#      'author': {'email': 'neverland251@gmail.com', 'name': 'KJI'},
#      'message': 'update IMS',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/neverland251/MainProject/commits/cdf4474ac097a7c8b5fce1590d739671057595aa'}]},
#   'public': True,
#   'created_at': '2019-05-14T16:33:33Z'},
#  {'id': '9624211500',
#   'type': 'PushEvent',
#   'actor': {'id': 33067562,
#    'login': 'Vanessa-rin',
#    'display_login': 'Vanessa-rin',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Vanessa-rin',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/33067562?'},
#   'repo': {'id': 176273964,
#    'name': 'Vanessa-rin/cram',
#    'url': 'https://api.github.com/repos/Vanessa-rin/cram'},
#   'payload': {'push_id': 3607745324,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/hardware-independence-projection',
#    'head': '77a3136ee2a371a73c5424e2fcaf54f1b10588f8',
#    'before': '59d2964dddf822957457ef8ea3b911179e7385d8',
#    'commits': [{'sha': '77a3136ee2a371a73c5424e2fcaf54f1b10588f8',
#      'author': {'email': 'hassouna@uni-bremen.de', 'name': 'vanessa-rin'},
#      'message': 'Revert "[urdf-proj] low-level contains now a function get-gripper-length"\n\nThis reverts commit 86c947a622652940e923a06d9c718c2a19b05333.',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Vanessa-rin/cram/commits/77a3136ee2a371a73c5424e2fcaf54f1b10588f8'}]},
#   'public': True,
#   'created_at': '2019-05-14T16:33:33Z'},
#  {'id': '9624211494',
#   'type': 'PushEvent',
#   'actor': {'id': 20181453,
#    'login': 'almmechanics',
#    'display_login': 'almmechanics',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/almmechanics',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/20181453?'},
#   'repo': {'id': 170840576,
#    'name': 'hmcts/cnp-aks-rbac-pipelines',
#    'url': 'https://api.github.com/repos/hmcts/cnp-aks-rbac-pipelines'},
#   'payload': {'push_id': 3607745317,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/CNP-1286-Pipelines',
#    'head': '75a5b3f78ff09023e9022504895d3b611857ea3d',
#    'before': '25518417d6d924464e7351e43c4b922fa2093cd2',
#    'commits': [{'sha': '75a5b3f78ff09023e9022504895d3b611857ea3d',
#      'author': {'email': 'martin.palmer@almmechanics.com',
#       'name': 'Martin Palmer'},
#      'message': 'removed redundant concat',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/hmcts/cnp-aks-rbac-pipelines/commits/75a5b3f78ff09023e9022504895d3b611857ea3d'}]},
#   'public': True,
#   'created_at': '2019-05-14T16:33:33Z',
#   'org': {'id': 22817111,
#    'login': 'hmcts',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/hmcts',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/22817111?'}},
#  {'id': '9624211493',
#   'type': 'PushEvent',
#   'actor': {'id': 8517910,
#    'login': 'LombiqBot',
#    'display_login': 'LombiqBot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/LombiqBot',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8517910?'},
#   'repo': {'id': 102737539,
#    'name': 'Lombiq/Hastlayer-SDK',
#    'url': 'https://api.github.com/repos/Lombiq/Hastlayer-SDK'},
#   'payload': {'push_id': 3607745314,
#    'size': 0,
#    'distinct_size': 0,
#    'ref': 'refs/heads/task/advtechdays13-demo',
#    'head': 'e02336faee35af9ecceb99e9b0b374adbae9b9ca',
#    'before': 'e02336faee35af9ecceb99e9b0b374adbae9b9ca',
#    'commits': []},
#   'public': True,
#   'created_at': '2019-05-14T16:33:33Z',
#   'org': {'id': 8158177,
#    'login': 'Lombiq',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/Lombiq',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8158177?'}},
#  {'id': '9624211488',
#   'type': 'PushEvent',
#   'actor': {'id': 17759664,
#    'login': 'LancerLix',
#    'display_login': 'LancerLix',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/LancerLix',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/17759664?'},
#   'repo': {'id': 53833077,
#    'name': 'LancerLix/STL-Study',
#    'url': 'https://api.github.com/repos/LancerLix/STL-Study'},
#   'payload': {'push_id': 3607745313,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'ab351d4b2099af4dadeb0dcf91aeb7d64bc4d600',
#    'before': '9517dfafb9e33d33fa6b0c6867653c444d7e3f47',
#    'commits': [{'sha': 'ab351d4b2099af4dadeb0dcf91aeb7d64bc4d600',
#      'author': {'email': 'lancer.k.lix@gmail.com', 'name': 'Lix'},
#      'message': 'sync last modify',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/LancerLix/STL-Study/commits/ab351d4b2099af4dadeb0dcf91aeb7d64bc4d600'}]},
#   'public': True,
#   'created_at': '2019-05-14T16:33:33Z'},
#  {'id': '9624211495',
#   'type': 'DeleteEvent',
#   'actor': {'id': 7669898,
#    'login': 'spacekookie',
#    'display_login': 'spacekookie',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/spacekookie',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/7669898?'},
#   'repo': {'id': 168696362,
#    'name': 'spacekookie/diesel',
#    'url': 'https://api.github.com/repos/spacekookie/diesel'},
#   'payload': {'ref': 'bump-barrel',
#    'ref_type': 'branch',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2019-05-14T16:33:33Z'},
#  {'id': '9624211483',
#   'type': 'PushEvent',
#   'actor': {'id': 16626109,
#    'login': 'MangrobanGit',
#    'display_login': 'MangrobanGit',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/MangrobanGit',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/16626109?'},
#   'repo': {'id': 186648282,
#    'name': 'MangrobanGit/dsc-3-27-12-knn-with-sklearn-lab-seattle-ds-career-040119',
#    'url': 'https://api.github.com/repos/MangrobanGit/dsc-3-27-12-knn-with-sklearn-lab-seattle-ds-career-040119'},
#   'payload': {'push_id': 3607745311,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/wip',
#    'head': '56e48e56fa69e1b8c2c73e411d14adee0907dd9f',
#    'before': 'a0273ef8b1474bd261a7b1cd95fd441b40f7377f',
#    'commits': [{'sha': '56e48e56fa69e1b8c2c73e411d14adee0907dd9f',
#      'author': {'email': 'werlindo.mangrobang@gmail.com',
#       'name': 'Werlindo Mangrobang'},
#      'message': 'Automatically backed up by Learn',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/MangrobanGit/dsc-3-27-12-knn-with-sklearn-lab-seattle-ds-career-040119/commits/56e48e56fa69e1b8c2c73e411d14adee0907dd9f'}]},
#   'public': True,
#   'created_at': '2019-05-14T16:33:33Z'},
#  {'id': '9624211474',
#   'type': 'IssueCommentEvent',
#   'actor': {'id': 1991427,
#    'login': 'taymonbeal',
#    'display_login': 'taymonbeal',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/taymonbeal',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/1991427?'},
#   'repo': {'id': 142703224,
#    'name': 'rtcharity/eahub.org',
#    'url': 'https://api.github.com/repos/rtcharity/eahub.org'},
#   'payload': {'action': 'created',
#    'issue': {'url': 'https://api.github.com/repos/rtcharity/eahub.org/issues/709',
#     'repository_url': 'https://api.github.com/repos/rtcharity/eahub.org',
#     'labels_url': 'https://api.github.com/repos/rtcharity/eahub.org/issues/709/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/rtcharity/eahub.org/issues/709/comments',
#     'events_url': 'https://api.github.com/repos/rtcharity/eahub.org/issues/709/events',
#     'html_url': 'https://github.com/rtcharity/eahub.org/issues/709',
#     'id': 443912641,
#     'node_id': 'MDU6SXNzdWU0NDM5MTI2NDE=',
#     'number': 709,
#     'title': 'Unable to `run web django-admin createcontainer`',
#     'user': {'login': 'michaltrzesimiech',
#      'id': 14195560,
#      'node_id': 'MDQ6VXNlcjE0MTk1NTYw',
#      'avatar_url': 'https://avatars2.githubusercontent.com/u/14195560?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/michaltrzesimiech',
#      'html_url': 'https://github.com/michaltrzesimiech',
#      'followers_url': 'https://api.github.com/users/michaltrzesimiech/followers',
#      'following_url': 'https://api.github.com/users/michaltrzesimiech/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/michaltrzesimiech/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/michaltrzesimiech/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/michaltrzesimiech/subscriptions',
#      'organizations_url': 'https://api.github.com/users/michaltrzesimiech/orgs',
#      'repos_url': 'https://api.github.com/users/michaltrzesimiech/repos',
#      'events_url': 'https://api.github.com/users/michaltrzesimiech/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/michaltrzesimiech/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'labels': [{'id': 1243408574,
#       'node_id': 'MDU6TGFiZWwxMjQzNDA4NTc0',
#       'url': 'https://api.github.com/repos/rtcharity/eahub.org/labels/Bug',
#       'name': 'Bug',
#       'color': '800000',
#       'default': False},
#      {'id': 1243414833,
#       'node_id': 'MDU6TGFiZWwxMjQzNDE0ODMz',
#       'url': 'https://api.github.com/repos/rtcharity/eahub.org/labels/DevOps',
#       'name': 'DevOps',
#       'color': 'ff8000',
#       'default': False}],
#     'state': 'open',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': {'url': 'https://api.github.com/repos/rtcharity/eahub.org/milestones/3',
#      'html_url': 'https://github.com/rtcharity/eahub.org/milestone/3',
#      'labels_url': 'https://api.github.com/repos/rtcharity/eahub.org/milestones/3/labels',
#      'id': 4077491,
#      'node_id': 'MDk6TWlsZXN0b25lNDA3NzQ5MQ==',
#      'number': 3,
#      'title': 'End Freeze',
#      'description': 'We are sufficiently confident in the stability of the site to resume major feature development, and are able to comfortably accept code contributions from people not on the core team. In particular, we have sufficient test coverage.',
#      'creator': {'login': 'taymonbeal',
#       'id': 1991427,
#       'node_id': 'MDQ6VXNlcjE5OTE0Mjc=',
#       'avatar_url': 'https://avatars0.githubusercontent.com/u/1991427?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/taymonbeal',
#       'html_url': 'https://github.com/taymonbeal',
#       'followers_url': 'https://api.github.com/users/taymonbeal/followers',
#       'following_url': 'https://api.github.com/users/taymonbeal/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/taymonbeal/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/taymonbeal/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/taymonbeal/subscriptions',
#       'organizations_url': 'https://api.github.com/users/taymonbeal/orgs',
#       'repos_url': 'https://api.github.com/users/taymonbeal/repos',
#       'events_url': 'https://api.github.com/users/taymonbeal/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/taymonbeal/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'open_issues': 26,
#      'closed_issues': 7,
#      'state': 'open',
#      'created_at': '2019-02-22T00:24:35Z',
#      'updated_at': '2019-05-14T13:22:35Z',
#      'due_on': '2019-05-25T07:00:00Z',
#      'closed_at': None},
#     'comments': 17,
#     'created_at': '2019-05-14T13:22:35Z',
#     'updated_at': '2019-05-14T16:33:33Z',
#     'closed_at': None,
#     'author_association': 'CONTRIBUTOR',
#     'body': 'Unable to set up local environment following the instructions in https://github.com/rtcharity/eahub.org\r\n\r\n```\r\nargo@argo:~/PycharmProjects/eahub.org$ docker-compose run web django-admin createcontainer\r\nCreating network "eahuborg_default" with the default driver\r\nPulling db (postgres:10.5)...\r\n10.5: Pulling from library/postgres\r\nf17d81b4b692: Pull complete\r\nc1f213be5edb: Pull complete\r\n9c79723dc510: Pull complete\r\n603a66804109: Pull complete\r\nb4f1b901e523: Pull complete\r\n99d9650419de: Pull complete\r\n02d87bb25bad: Pull complete\r\n333a24caa91e: Pull complete\r\n9cab7935ece2: Pull complete\r\n5977bf28967d: Pull complete\r\n74ddd26cf783: Pull complete\r\n07b76fcb42dd: Pull complete\r\n7da7962ee038: Pull complete\r\n0ddc5f8e0873: Pull complete\r\nCreating eahuborg_db_1 ... \r\nCreating eahuborg_cache_1 ... \r\nCreating eahuborg_objstore_1 ... \r\nCreating eahuborg_mail_1     ... error\r\n\r\nERROR: for eahuborg_mail_1  Cannot start service mail: driver failed programming external connectivity on endpoint eahuborg_mail_1 (2a7abd507310d387404c204ffab4Creating eahuborg_objstore_1 ... error\r\neady allocated\r\n\r\nCreating eahuborg_db_1       ... done\r\nCreating eahuborg_cache_1    ... done\r\n2a2aa3ec249b02a744e932615dba5c2aedbff6b36dab7099): Bind for 0.0.0.0:8002 failed: port is already allocated\r\n\r\nERROR: for mail  Cannot start service mail: driver failed programming external connectivity on endpoint eahuborg_mail_1 (2a7abd507310d387404c204ffab497ef711e13fee63cc1f31290b2cfdbc94810): Bind for 0.0.0.0:8001 failed: port is already allocated\r\n\r\nERROR: for objstore  Cannot start service objstore: driver failed programming external connectivity on endpoint eahuborg_objstore_1 (70ce6af05364f85a2a2aa3ec249b02a744e932615dba5c2aedbff6b36dab7099): Bind for 0.0.0.0:8002 failed: port is already allocated\r\nERROR: Encountered errors while bringing up the project.\r\n\r\n```'},
#    'comment': {'url': 'https://api.github.com/repos/rtcharity/eahub.org/issues/comments/492312893',
#     'html_url': 'https://github.com/rtcharity/eahub.org/issues/709#issuecomment-492312893',
#     'issue_url': 'https://api.github.com/repos/rtcharity/eahub.org/issues/709',
#     'id': 492312893,
#     'node_id': 'MDEyOklzc3VlQ29tbWVudDQ5MjMxMjg5Mw==',
#     'user': {'login': 'taymonbeal',
#      'id': 1991427,
#      'node_id': 'MDQ6VXNlcjE5OTE0Mjc=',
#      'avatar_url': 'https://avatars0.githubusercontent.com/u/1991427?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/taymonbeal',
#      'html_url': 'https://github.com/taymonbeal',
#      'followers_url': 'https://api.github.com/users/taymonbeal/followers',
#      'following_url': 'https://api.github.com/users/taymonbeal/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/taymonbeal/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/taymonbeal/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/taymonbeal/subscriptions',
#      'organizations_url': 'https://api.github.com/users/taymonbeal/orgs',
#      'repos_url': 'https://api.github.com/users/taymonbeal/repos',
#      'events_url': 'https://api.github.com/users/taymonbeal/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/taymonbeal/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'created_at': '2019-05-14T16:33:33Z',
#     'updated_at': '2019-05-14T16:33:33Z',
#     'author_association': 'MEMBER',
#     'body': '`docker-compose run web ls /code/eahub`'}},
#   'public': True,
#   'created_at': '2019-05-14T16:33:33Z',
#   'org': {'id': 6238562,
#    'login': 'rtcharity',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/rtcharity',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/6238562?'}},
#  {'id': '9624211479',
#   'type': 'PushEvent',
#   'actor': {'id': 7875419,
#    'login': 'mitchellporter',
#    'display_login': 'mitchellporter',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/mitchellporter',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/7875419?'},
#   'repo': {'id': 186656715,
#    'name': 'mitchellporter/mitchellporter.github.io',
#    'url': 'https://api.github.com/repos/mitchellporter/mitchellporter.github.io'},
#   'payload': {'push_id': 3607745310,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '6f321be7b25fc30b05af0902754c5e110be76be5',
#    'before': 'ba31bd739d6e95ee451581ec761b6dfdc8103a8f',
#    'commits': [{'sha': '6f321be7b25fc30b05af0902754c5e110be76be5',
#      'author': {'email': 'mitchellporter@gmail.com',
#       'name': 'Mitchell Porter'},
#      'message': 'Create CNAME',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/mitchellporter/mitchellporter.github.io/commits/6f321be7b25fc30b05af0902754c5e110be76be5'}]},
#   'public': True,
#   'created_at': '2019-05-14T16:33:33Z'},
#  {'id': '9624211480',
#   'type': 'WatchEvent',
#   'actor': {'id': 16114237,
#    'login': 'yepoke',
#    'display_login': 'yepoke',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/yepoke',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/16114237?'},
#   'repo': {'id': 128624453,
#    'name': 'NervJS/taro',
#    'url': 'https://api.github.com/repos/NervJS/taro'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2019-05-14T16:33:33Z',
#   'org': {'id': 30794937,
#    'login': 'NervJS',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/NervJS',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/30794937?'}},
#  {'id': '9624211478',
#   'type': 'CreateEvent',
#   'actor': {'id': 49865193,
#    'login': 'benedicaprio',
#    'display_login': 'benedicaprio',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/benedicaprio',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/49865193?'},
#   'repo': {'id': 186660980,
#    'name': 'elegant-os/system_sepolicy',
#    'url': 'https://api.github.com/repos/elegant-os/system_sepolicy'},
#   'payload': {'ref': 'pie',
#    'ref_type': 'branch',
#    'master_branch': 'pie',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2019-05-14T16:33:33Z',
#   'org': {'id': 50540699,
#    'login': 'elegant-os',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/elegant-os',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/50540699?'}},
#  {'id': '9624211468',
#   'type': 'PushEvent',
#   'actor': {'id': 12146082,
#    'login': 'fenxu',
#    'display_login': 'fenxu',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/fenxu',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/12146082?'},
#   'repo': {'id': 127992298,
#    'name': 'OPS-E2E-PPE/dotnet-api-docs',
#    'url': 'https://api.github.com/repos/OPS-E2E-PPE/dotnet-api-docs'},
#   'payload': {'push_id': 3607745305,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master_working_branch',
#    'head': '8c56ad32256cc31b6b25a5e704da0209f5000284',
#    'before': '4dd2459773e5956525c4e3b1f06c12c01e2635c9',
#    'commits': [{'sha': '8c56ad32256cc31b6b25a5e704da0209f5000284',
#      'author': {'email': 'chin.sy.des@gmail.com', 'name': 'Desmond Chin'},
#      'message': 'simplify description (#2446)',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/OPS-E2E-PPE/dotnet-api-docs/commits/8c56ad32256cc31b6b25a5e704da0209f5000284'}]},
#   'public': True,
#   'created_at': '2019-05-14T16:33:33Z',
#   'org': {'id': 24789825,
#    'login': 'OPS-E2E-PPE',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/OPS-E2E-PPE',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/24789825?'}},
#  {'id': '9624211467',
#   'type': 'PushEvent',
#   'actor': {'id': 47563834,
#    'login': 'juanspinelli',
#    'display_login': 'juanspinelli',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/juanspinelli',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/47563834?'},
#   'repo': {'id': 186457086,
#    'name': 'juanspinelli/all',
#    'url': 'https://api.github.com/repos/juanspinelli/all'},
#   'payload': {'push_id': 3607745304,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'abee7fdaa0f17a6d07f52f74d26a6d0005f0fcb7',
#    'before': 'f3e7540d62cc9fc4b4fd9ae01d1f3a03cfc9f455',
#    'commits': [{'sha': 'abee7fdaa0f17a6d07f52f74d26a6d0005f0fcb7',
#      'author': {'email': 'jmspinelliok@gmail.com', 'name': 'JuanSpinelli'},
#      'message': 'Arreglo',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/juanspinelli/all/commits/abee7fdaa0f17a6d07f52f74d26a6d0005f0fcb7'}]},
#   'public': True,
#   'created_at': '2019-05-14T16:33:33Z'},
#  {'id': '9624211464',
#   'type': 'PushEvent',
#   'actor': {'id': 20407524,
#    'login': 'k8s-ci-robot',
#    'display_login': 'k8s-ci-robot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/k8s-ci-robot',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/20407524?'},
#   'repo': {'id': 62091339,
#    'name': 'kubernetes/kops',
#    'url': 'https://api.github.com/repos/kubernetes/kops'},
#   'payload': {'push_id': 3607745278,
#    'size': 4,
#    'distinct_size': 4,
#    'ref': 'refs/heads/master',
#    'head': 'c6d392ea39e1eeaddb79b2b16b0fa150301814a5',
#    'before': '592062dfce083450f878b3e36be7e6640e7cf533',
#    'commits': [{'sha': '247cd78851d9274e10a475612ff22c7e4d3c07a7',
#      'author': {'email': 'justinsb@google.com', 'name': 'Justin SB'},
#      'message': 'Use kubebuilder libraries to generate CRDs\n\n(Add the dependency on kubebuilder also)',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/kubernetes/kops/commits/247cd78851d9274e10a475612ff22c7e4d3c07a7'},
#     {'sha': '10964d416ea4df5d85294df3ca5c9f10efd1d067',
#      'author': {'email': 'justinsb@google.com', 'name': 'Justin SB'},
#      'message': 'Update vendor directory',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/kubernetes/kops/commits/10964d416ea4df5d85294df3ca5c9f10efd1d067'},
#     {'sha': '44fa27363030ee8c984cee06c87a9661b791d7f5',
#      'author': {'email': 'justinsb@google.com', 'name': 'Justin SB'},
#      'message': 'Generate CRDs',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/kubernetes/kops/commits/44fa27363030ee8c984cee06c87a9661b791d7f5'},
#     {'sha': 'c6d392ea39e1eeaddb79b2b16b0fa150301814a5',
#      'author': {'email': 'k8s-ci-robot@users.noreply.github.com',
#       'name': 'Kubernetes Prow Robot'},
#      'message': 'Merge pull request #6891 from justinsb/use_kubebuilder_to_generate_crds\n\nGenerate CRDs for kops API types',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/kubernetes/kops/commits/c6d392ea39e1eeaddb79b2b16b0fa150301814a5'}]},
#   'public': True,
#   'created_at': '2019-05-14T16:33:33Z',
#   'org': {'id': 13629408,
#    'login': 'kubernetes',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/kubernetes',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/13629408?'}},
#  {'id': '9624211455',
#   'type': 'PushEvent',
#   'actor': {'id': 23659015,
#    'login': 'Holmesc16',
#    'display_login': 'Holmesc16',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Holmesc16',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/23659015?'},
#   'repo': {'id': 186644392,
#    'name': 'CityOfLewisvilleTexas/onetwothree',
#    'url': 'https://api.github.com/repos/CityOfLewisvilleTexas/onetwothree'},
#   'payload': {'push_id': 3607745289,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'fcade7fe4830934e6351e237617460f1ba9a2987',
#    'before': '0368bb3726d1d366d6148329fc9178bde5e4969e',
#    'commits': [{'sha': 'fcade7fe4830934e6351e237617460f1ba9a2987',
#      'author': {'email': 'holmesc16@gmail.com', 'name': 'Holmesc16'},
#      'message': 'tiny commit',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/CityOfLewisvilleTexas/onetwothree/commits/fcade7fe4830934e6351e237617460f1ba9a2987'}]},
#   'public': True,
#   'created_at': '2019-05-14T16:33:33Z',
#   'org': {'id': 17008907,
#    'login': 'CityOfLewisvilleTexas',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/CityOfLewisvilleTexas',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/17008907?'}},
#  {'id': '9624211458',
#   'type': 'PushEvent',
#   'actor': {'id': 7966535,
#    'login': 'wnateg',
#    'display_login': 'wnateg',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/wnateg',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/7966535?'},
#   'repo': {'id': 186661095,
#    'name': 'wnateg/dompdf',
#    'url': 'https://api.github.com/repos/wnateg/dompdf'},
#   'payload': {'push_id': 3607745292,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'fb13b0c0bae3b7b272b1f7ca4121918dcb9dd52b',
#    'before': 'd30679a47a067a69540c988405cb675404898acc',
#    'commits': [{'sha': 'fb13b0c0bae3b7b272b1f7ca4121918dcb9dd52b',
#      'author': {'email': 'wnateg@gmail.com', 'name': 'wnateg'},
#      'message': 'Update Cpdf.php',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/wnateg/dompdf/commits/fb13b0c0bae3b7b272b1f7ca4121918dcb9dd52b'}]},
#   'public': True,
#   'created_at': '2019-05-14T16:33:33Z'},
#  {'id': '9624211461',
#   'type': 'PushEvent',
#   'actor': {'id': 6162685,
#    'login': 'bparment1',
#    'display_login': 'bparment1',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/bparment1',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/6162685?'},
#   'repo': {'id': 99149018,
#    'name': 'bparment1/earth_engine_google',
#    'url': 'https://api.github.com/repos/bparment1/earth_engine_google'},
#   'payload': {'push_id': 3607745294,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'c430bd4d8a0b7c2aec86083c43a4f90f486fff48',
#    'before': '62377d9979bf4536684145a62589c592bbda58a1',
#    'commits': [{'sha': 'c430bd4d8a0b7c2aec86083c43a4f90f486fff48',
#      'author': {'email': 'bparmentier@sshgw02.research.sesync.org',
#       'name': 'Benoit Parmentier'},
#      'message': 'ROC with 100 tresholds and minor modfications',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/bparment1/earth_engine_google/commits/c430bd4d8a0b7c2aec86083c43a4f90f486fff48'}]},
#   'public': True,
#   'created_at': '2019-05-14T16:33:33Z'},
#  {'id': '9624211453',
#   'type': 'PushEvent',
#   'actor': {'id': 44496275,
#    'login': '0b3d',
#    'display_login': '0b3d',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/0b3d',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/44496275?'},
#   'repo': {'id': 168737595,
#    'name': '0b3d/street2vec',
#    'url': 'https://api.github.com/repos/0b3d/street2vec'},
#   'payload': {'push_id': 3607745284,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/s2v_pytorch',
#    'head': '0b715630fd0370706457e4752a6f91dccfd0c291',
#    'before': 'b29f8597c42ca8e326c25825e08f36f318e1a16d',
#    'commits': [{'sha': '0b715630fd0370706457e4752a6f91dccfd0c291',
#      'author': {'email': 'samanoabonce@gmail.com', 'name': '0b3d'},
#      'message': 'Added option to fine-tune resnet50 pretrained in places365',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/0b3d/street2vec/commits/0b715630fd0370706457e4752a6f91dccfd0c291'}]},
#   'public': True,
#   'created_at': '2019-05-14T16:33:33Z'},
#  {'id': '9624211443',
#   'type': 'PushEvent',
#   'actor': {'id': 48493078,
#    'login': 'hkicin1',
#    'display_login': 'hkicin1',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/hkicin1',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/48493078?'},
#   'repo': {'id': 185559369,
#    'name': 'hkicin1/Tutorijal-7',
#    'url': 'https://api.github.com/repos/hkicin1/Tutorijal-7'},
#   'payload': {'push_id': 3607745281,
#    'size': 3,
#    'distinct_size': 3,
#    'ref': 'refs/heads/master',
#    'head': '628650b682664d575c3620f262bd8c7edc8a1b37',
#    'before': '6eec4c9a55a20591f046c7773e747103d51b16ce',
#    'commits': [{'sha': '20c7339099faa9a9e04b51497bacfb585abcca13',
#      'author': {'email': 'hkicin1@etf.unsa.ba', 'name': 'hkicin1'},
#      'message': 'Elementi niza promjenjeni u Integer umjesto u int.',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/hkicin1/Tutorijal-7/commits/20c7339099faa9a9e04b51497bacfb585abcca13'},
#     {'sha': '0f97a3324254829263e6a48689dcb199b5340672',
#      'author': {'email': 'hkicin1@etf.unsa.ba', 'name': 'hkicin1'},
#      'message': 'Treći zadatak, sortiranje pomoću Java Streams API.',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/hkicin1/Tutorijal-7/commits/0f97a3324254829263e6a48689dcb199b5340672'},
#     {'sha': '628650b682664d575c3620f262bd8c7edc8a1b37',
#      'author': {'email': 'hkicin1@etf.unsa.ba', 'name': 'hkicin1'},
#      'message': 'Prepravljena imena varijabli za veličinu niza i unos.',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/hkicin1/Tutorijal-7/commits/628650b682664d575c3620f262bd8c7edc8a1b37'}]},
#   'public': True,
#   'created_at': '2019-05-14T16:33:33Z'},
#  {'id': '9624211446',
#   'type': 'CreateEvent',
#   'actor': {'id': 7911893,
#    'login': 'slskopytko',
#    'display_login': 'slskopytko',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/slskopytko',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/7911893?'},
#   'repo': {'id': 186661208,
#    'name': 'slskopytko/mcbrypvwsb',
#    'url': 'https://api.github.com/repos/slskopytko/mcbrypvwsb'},
#   'payload': {'ref': None,
#    'ref_type': 'repository',
#    'master_branch': 'master',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2019-05-14T16:33:33Z'},
#  {'id': '9624211442',
#   'type': 'WatchEvent',
#   'actor': {'id': 30937892,
#    'login': 'Babylonehy',
#    'display_login': 'Babylonehy',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Babylonehy',
# ...
#       'teams_url': 'https://api.github.com/repos/jamesmcclain/DockerCoreHelper/teams',
#       'hooks_url': 'https://api.github.com/repos/jamesmcclain/DockerCoreHelper/hooks',
#       'issue_events_url': 'https://api.github.com/repos/jamesmcclain/DockerCoreHelper/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/jamesmcclain/DockerCoreHelper/events',
#       'assignees_url': 'https://api.github.com/repos/jamesmcclain/DockerCoreHelper/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/jamesmcclain/DockerCoreHelper/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/jamesmcclain/DockerCoreHelper/tags',
#       'blobs_url': 'https://api.github.com/repos/jamesmcclain/DockerCoreHelper/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/jamesmcclain/DockerCoreHelper/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/jamesmcclain/DockerCoreHelper/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/jamesmcclain/DockerCoreHelper/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/jamesmcclain/DockerCoreHelper/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/jamesmcclain/DockerCoreHelper/languages',
#       'stargazers_url': 'https://api.github.com/repos/jamesmcclain/DockerCoreHelper/stargazers',
#       'contributors_url': 'https://api.github.com/repos/jamesmcclain/DockerCoreHelper/contributors',
#       'subscribers_url': 'https://api.github.com/repos/jamesmcclain/DockerCoreHelper/subscribers',
#       'subscription_url': 'https://api.github.com/repos/jamesmcclain/DockerCoreHelper/subscription',
#       'commits_url': 'https://api.github.com/repos/jamesmcclain/DockerCoreHelper/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/jamesmcclain/DockerCoreHelper/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/jamesmcclain/DockerCoreHelper/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/jamesmcclain/DockerCoreHelper/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/jamesmcclain/DockerCoreHelper/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/jamesmcclain/DockerCoreHelper/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/jamesmcclain/DockerCoreHelper/merges',
#       'archive_url': 'https://api.github.com/repos/jamesmcclain/DockerCoreHelper/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/jamesmcclain/DockerCoreHelper/downloads',
#       'issues_url': 'https://api.github.com/repos/jamesmcclain/DockerCoreHelper/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/jamesmcclain/DockerCoreHelper/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/jamesmcclain/DockerCoreHelper/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/jamesmcclain/DockerCoreHelper/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/jamesmcclain/DockerCoreHelper/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/jamesmcclain/DockerCoreHelper/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/jamesmcclain/DockerCoreHelper/deployments',
#       'created_at': '2019-05-12T23:54:35Z',
#       'updated_at': '2019-05-14T16:30:51Z',
#       'pushed_at': '2019-05-14T16:33:13Z',
#       'git_url': 'git://github.com/jamesmcclain/DockerCoreHelper.git',
#       'ssh_url': 'git@github.com:jamesmcclain/DockerCoreHelper.git',
#       'clone_url': 'https://github.com/jamesmcclain/DockerCoreHelper.git',
#       'svn_url': 'https://github.com/jamesmcclain/DockerCoreHelper',
#       'homepage': None,
#       'size': 6,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'C',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 1,
#       'license': None,
#       'forks': 0,
#       'open_issues': 1,
#       'watchers': 0,
#       'default_branch': 'master'}},
#     'base': {'label': 'jamesmcclain:master',
#      'ref': 'master',
#      'sha': 'e690ca0b32fe7ea45e6adac8e00810ab166bb26b',
#      'user': {'login': 'jamesmcclain',
#       'id': 11281373,
#       'node_id': 'MDQ6VXNlcjExMjgxMzcz',
#       'avatar_url': 'https://avatars1.githubusercontent.com/u/11281373?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/jamesmcclain',
#       'html_url': 'https://github.com/jamesmcclain',
#       'followers_url': 'https://api.github.com/users/jamesmcclain/followers',
#       'following_url': 'https://api.github.com/users/jamesmcclain/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/jamesmcclain/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/jamesmcclain/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/jamesmcclain/subscriptions',
#       'organizations_url': 'https://api.github.com/users/jamesmcclain/orgs',
#       'repos_url': 'https://api.github.com/users/jamesmcclain/repos',
#       'events_url': 'https://api.github.com/users/jamesmcclain/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/jamesmcclain/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 186316667,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkxODYzMTY2Njc=',
#       'name': 'DockerCoreHelper',
#       'full_name': 'jamesmcclain/DockerCoreHelper',
#       'private': False,
#       'owner': {'login': 'jamesmcclain',
#        'id': 11281373,
#        'node_id': 'MDQ6VXNlcjExMjgxMzcz',
#        'avatar_url': 'https://avatars1.githubusercontent.com/u/11281373?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/jamesmcclain',
#        'html_url': 'https://github.com/jamesmcclain',
#        'followers_url': 'https://api.github.com/users/jamesmcclain/followers',
#        'following_url': 'https://api.github.com/users/jamesmcclain/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/jamesmcclain/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/jamesmcclain/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/jamesmcclain/subscriptions',
#        'organizations_url': 'https://api.github.com/users/jamesmcclain/orgs',
#        'repos_url': 'https://api.github.com/users/jamesmcclain/repos',
#        'events_url': 'https://api.github.com/users/jamesmcclain/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/jamesmcclain/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/jamesmcclain/DockerCoreHelper',
#       'description': None,
#       'fork': False,
#       'url': 'https://api.github.com/repos/jamesmcclain/DockerCoreHelper',
#       'forks_url': 'https://api.github.com/repos/jamesmcclain/DockerCoreHelper/forks',
#       'keys_url': 'https://api.github.com/repos/jamesmcclain/DockerCoreHelper/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/jamesmcclain/DockerCoreHelper/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/jamesmcclain/DockerCoreHelper/teams',
#       'hooks_url': 'https://api.github.com/repos/jamesmcclain/DockerCoreHelper/hooks',
#       'issue_events_url': 'https://api.github.com/repos/jamesmcclain/DockerCoreHelper/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/jamesmcclain/DockerCoreHelper/events',
#       'assignees_url': 'https://api.github.com/repos/jamesmcclain/DockerCoreHelper/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/jamesmcclain/DockerCoreHelper/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/jamesmcclain/DockerCoreHelper/tags',
#       'blobs_url': 'https://api.github.com/repos/jamesmcclain/DockerCoreHelper/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/jamesmcclain/DockerCoreHelper/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/jamesmcclain/DockerCoreHelper/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/jamesmcclain/DockerCoreHelper/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/jamesmcclain/DockerCoreHelper/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/jamesmcclain/DockerCoreHelper/languages',
#       'stargazers_url': 'https://api.github.com/repos/jamesmcclain/DockerCoreHelper/stargazers',
#       'contributors_url': 'https://api.github.com/repos/jamesmcclain/DockerCoreHelper/contributors',
#       'subscribers_url': 'https://api.github.com/repos/jamesmcclain/DockerCoreHelper/subscribers',
#       'subscription_url': 'https://api.github.com/repos/jamesmcclain/DockerCoreHelper/subscription',
#       'commits_url': 'https://api.github.com/repos/jamesmcclain/DockerCoreHelper/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/jamesmcclain/DockerCoreHelper/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/jamesmcclain/DockerCoreHelper/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/jamesmcclain/DockerCoreHelper/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/jamesmcclain/DockerCoreHelper/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/jamesmcclain/DockerCoreHelper/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/jamesmcclain/DockerCoreHelper/merges',
#       'archive_url': 'https://api.github.com/repos/jamesmcclain/DockerCoreHelper/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/jamesmcclain/DockerCoreHelper/downloads',
#       'issues_url': 'https://api.github.com/repos/jamesmcclain/DockerCoreHelper/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/jamesmcclain/DockerCoreHelper/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/jamesmcclain/DockerCoreHelper/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/jamesmcclain/DockerCoreHelper/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/jamesmcclain/DockerCoreHelper/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/jamesmcclain/DockerCoreHelper/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/jamesmcclain/DockerCoreHelper/deployments',
#       'created_at': '2019-05-12T23:54:35Z',
#       'updated_at': '2019-05-14T16:30:51Z',
#       'pushed_at': '2019-05-14T16:33:13Z',
#       'git_url': 'git://github.com/jamesmcclain/DockerCoreHelper.git',
#       'ssh_url': 'git@github.com:jamesmcclain/DockerCoreHelper.git',
#       'clone_url': 'https://github.com/jamesmcclain/DockerCoreHelper.git',
#       'svn_url': 'https://github.com/jamesmcclain/DockerCoreHelper',
#       'homepage': None,
#       'size': 6,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'C',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 1,
#       'license': None,
#       'forks': 0,
#       'open_issues': 1,
#       'watchers': 0,
#       'default_branch': 'master'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/jamesmcclain/DockerCoreHelper/pulls/2'},
#      'html': {'href': 'https://github.com/jamesmcclain/DockerCoreHelper/pull/2'},
#      'issue': {'href': 'https://api.github.com/repos/jamesmcclain/DockerCoreHelper/issues/2'},
#      'comments': {'href': 'https://api.github.com/repos/jamesmcclain/DockerCoreHelper/issues/2/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/jamesmcclain/DockerCoreHelper/pulls/2/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/jamesmcclain/DockerCoreHelper/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/jamesmcclain/DockerCoreHelper/pulls/2/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/jamesmcclain/DockerCoreHelper/statuses/0f0c18e2fc5d7d785a082e480a6a4108cb3aeb5c'}},
#     'author_association': 'OWNER',
#     'merged': False,
#     'mergeable': None,
#     'rebaseable': None,
#     'mergeable_state': 'unknown',
#     'merged_by': None,
#     'comments': 0,
#     'review_comments': 0,
#     'maintainer_can_modify': False,
#     'commits': 1,
#     'additions': 1,
#     'deletions': 0,
#     'changed_files': 2}},
#   'public': True,
#   'created_at': '2019-05-14T16:33:33Z'},
#  {'id': '9624211395',
#   'type': 'PushEvent',
#   'actor': {'id': 47872634,
#    'login': 'l10nbot',
#    'display_login': 'l10nbot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/l10nbot',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/47872634?'},
#   'repo': {'id': 128474008,
#    'name': 'mui-org/material-ui-docs',
#    'url': 'https://api.github.com/repos/mui-org/material-ui-docs'},
#   'payload': {'push_id': 3607745260,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/l10n',
#    'head': '20e432f544a0cf0d2297428f03d5146c5d5a8e79',
#    'before': 'c9ec02c258b46055cf2e2276f38b88c4c15a82df',
#    'commits': [{'sha': '20e432f544a0cf0d2297428f03d5146c5d5a8e79',
#      'author': {'email': '47872634+l10nbot@users.noreply.github.com',
#       'name': 'l10nbot'},
#      'message': 'New translations selects.md (Spanish)',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/mui-org/material-ui-docs/commits/20e432f544a0cf0d2297428f03d5146c5d5a8e79'}]},
#   'public': True,
#   'created_at': '2019-05-14T16:33:32Z',
#   'org': {'id': 33663932,
#    'login': 'mui-org',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/mui-org',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/33663932?'}},
#  {'id': '9624211420',
#   'type': 'PushEvent',
#   'actor': {'id': 44175291,
#    'login': 'rich0024',
#    'display_login': 'rich0024',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/rich0024',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/44175291?'},
#   'repo': {'id': 186661055,
#    'name': 'rich0024/sinatra-integrating-models-walkthrough-online-web-pt-011419',
#    'url': 'https://api.github.com/repos/rich0024/sinatra-integrating-models-walkthrough-online-web-pt-011419'},
#   'payload': {'push_id': 3607745270,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/wip',
#    'head': '218f9e6ded231e034431ae2cc9620f6bc9f75b5a',
#    'before': '101c1ffdd3c4e0ae2540ff80d329c60b363dbb8e',
#    'commits': [{'sha': '218f9e6ded231e034431ae2cc9620f6bc9f75b5a',
#      'author': {'email': 'yance0022@gmail.com', 'name': 'Richard Yance'},
#      'message': 'Automatically backed up by Learn',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/rich0024/sinatra-integrating-models-walkthrough-online-web-pt-011419/commits/218f9e6ded231e034431ae2cc9620f6bc9f75b5a'}]},
#   'public': True,
#   'created_at': '2019-05-14T16:33:33Z'},
#  {'id': '9624211405',
#   'type': 'DeleteEvent',
#   'actor': {'id': 1348,
#    'login': 'nwjsmith',
#    'display_login': 'nwjsmith',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/nwjsmith',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/1348?'},
#   'repo': {'id': 164702370,
#    'name': 'CircleCITestOrg/smoke-test-test-repo',
#    'url': 'https://api.github.com/repos/CircleCITestOrg/smoke-test-test-repo'},
#   'payload': {'ref': 'build-remote-docker-2019-05-05T23-59-23',
#    'ref_type': 'branch',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2019-05-14T16:33:32Z',
#   'org': {'id': 32499712,
#    'login': 'CircleCITestOrg',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/CircleCITestOrg',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/32499712?'}}]

# %%
#create a post request from https://httpbin.org/post and view it in json format

r = requests.post("https://httpbin.org/post", data = {'key':'value'}) #put url and data format here!
r.json()
# Out:
# {'args': {},
#  'data': '',
#  'files': {},
#  'form': {'key': 'value'},
#  'headers': {'Accept': '*/*',
#   'Accept-Encoding': 'gzip, deflate',
#   'Content-Length': '9',
#   'Content-Type': 'application/x-www-form-urlencoded',
#   'Host': 'httpbin.org',
#   'User-Agent': 'python-requests/2.21.0'},
#  'json': None,
#  'origin': '63.98.217.210, 63.98.217.210',
#  'url': 'https://httpbin.org/post'}

# %% [markdown]
# ### Checking out the status of your request
#
# #### Types of status codes
# 1xx - Informational responses
#
# 2xx - Success
# - 200 OK
# - 201 Created
# - 204 No Content
#
# 3xx - Redirection
#
# - 301 Moved Permanently (permanent URL redirection)
# - 304 Not Modified (A conditional GET or HEAD request has been received and would have resulted in a 200 OK response if it were not for the fact that the condition evaluated to false.)
#
# 4xx - Client errors
#
# - 400 Bad Request
# - 401 Unauthorized
# - 403 Forbidden
# - 404 Not Found
#
# 5xx - Server errors
#
# - 500 Internal Server Error

# %%
#get the status of your post request
r.status_code
# Out:
# 200

# %%
#get status code for a "broken" link

r = requests.get('https://api.github.com/fake-ending')
r.status_code
# Out:
# 404

# %% [markdown]
# ### Other functionality
#
# Let's say you are looking at an API for a car rental company like Hertz, or maybe even Zipcar.
#
# The following different requests will generate these different responses.
#
# |Request        | Result        |
# |-------------|-------------|
# |GET /stores/   | User sees the list of stores|
# |GET /rentals/  | User sees the history of car rentals|
# |POST /rentals/ | User rents a car|
# |PUT /rentals/{id}/| User changes destination store|
# |DELETE /rentals/{id}/| User cancels the active car rental|

# %%
rental_json = [{
    "id": 1,
    "name": "John St",
    "location": [29, 95],
    "available_cars_quantity": 10
},
{
    "id": 2,
    "name": "Scott St.",
    "location": [29.5, 95.7],
    "available_cars_quantity": 2
}]

# %% [markdown]
# #### A note on errors and exceptions with the Requests library
#
# There are a number of exceptions and error codes you need to be familiar with when using the Requests library in Python.
#
# - The Requests library will raise a ConnectionError exception if there is a network problem like a DNS failure, or refused connection.
# - These are rare, but with invalid HTTP responses, Requests will also raise an HTTPError exception.
# - A Timeout exception will be raised if a request times out.
# - If and when a request exceeds the preconfigured number of maximum redirections, then a TooManyRedirects exception will be raised

# %% [markdown]
# Now that we know a bit more about APIs and how to interact with them in python, let's actually investigate an API from scratch.
#
# To start, go over to the API documentation at:
#
# https://dev.socrata.com/foundry/data.cityofnewyork.us/fhrw-4uyv
#
#
# <img src="311_api_docs.png">

# %% [markdown]
# ## Make an initial API call to retrieve 311 complaints from a neighborhood or zip code of your choice in New York City.

# %%
# Install before running 
# !pip install sodapy

# %% [markdown]
# #### Tokenize yourself, B!
#
# https://dev.socrata.com/foundry/data.cityofnewyork.us/fhrw-4uyv
#
# Scroll down and click to sign up for an app token! This is instantaneous and simple. No credit cards required!

# %%
# Formulation 1


token = 'qD4ooggg34psl2OFfaytbayIW' 


import pandas as pd
from sodapy import Socrata

# Unauthenticated client only works with public data sets. Note 'None'
# in place of application token, and no username or password:
client = Socrata("data.cityofnewyork.us", token)

# Example authenticated client (needed for non-public datasets):
# client = Socrata(data.cityofnewyork.us,
#                  MyAppToken,
#                  userame="user@example.com",
#                  password="AFakePassword")

# First 2000 results, returned as JSON from API / converted to Python list of
# dictionaries by sodapy.
results = client.get("fhrw-4uyv", incident_zip = '10004', limit=1000)

# %%
# Formulation 2
import requests
import pandas as pd

zip_code = '10004'

# can't figure out date ranges at the moment...
start_date = '2018-01-01T12:00:00'
end_date = '2018-02-01T12:00:00'

# create pull request based on parameters
# https://data.cityofnewyork.us/Social-Services/311-Service-Requests-from-2010-to-Present/erm2-nwe9 click API

url = "https://data.cityofnewyork.us/resource/fhrw-4uyv.json?incident_zip={}".format(zip_code)

# do the pull
response = requests.get(url)
if response.status_code == 200:
    data = response.json()
else:
    print('Hit an error.')

# %% [markdown]
# ## Briefly Explore the Structure of the Response You Received.

# %%
#Formulation 1
type(results)
# Out:
# list

# %%
len(results)
# Out:
# 1000

# %%
results[0]
# Out:
# {'address_type': 'PLACENAME',
#  'agency': 'NYPD',
#  'agency_name': 'New York City Police Department',
#  'borough': 'MANHATTAN',
#  'city': 'NEW YORK',
#  'closed_date': '2019-05-11T14:44:10.000',
#  'community_board': '01 MANHATTAN',
#  'complaint_type': 'Panhandling',
#  'created_date': '2019-05-11T14:21:35.000',
#  'cross_street_1': 'PETER MINUIT PLACE',
#  'cross_street_2': 'SOUTH STREET',
#  'descriptor': 'N/A',
#  'due_date': '2019-05-11T22:21:35.000',
#  'facility_type': 'Precinct',
#  'incident_zip': '10004',
#  'landmark': 'SI FERRY TERMINAL',
#  'latitude': '40.70096726219546',
#  'location': {'type': 'Point',
#   'coordinates': [-74.013134888845, 40.700967262195]},
#  'location_type': 'Street/Sidewalk',
#  'longitude': '-74.01313488884514',
#  'open_data_channel_type': 'PHONE',
#  'park_borough': 'MANHATTAN',
#  'park_facility_name': 'Unspecified',
#  'resolution_action_updated_date': '2019-05-11T14:44:10.000',
#  'resolution_description': 'The Police Department responded and upon arrival those responsible for the condition were gone.',
#  'status': 'Closed',
#  'unique_key': '42649886',
#  'x_coordinate_state_plane': '980608',
#  'y_coordinate_state_plane': '194658'}

# %%
# Formulation 2
print(type(data))
# Out:
# <class 'list'>

# %%
len(data)
# Out:
# 1000

# %%
data[0]
# Out:
# {'address_type': 'PLACENAME',
#  'agency': 'NYPD',
#  'agency_name': 'New York City Police Department',
#  'borough': 'MANHATTAN',
#  'city': 'NEW YORK',
#  'closed_date': '2019-05-11T14:44:10.000',
#  'community_board': '01 MANHATTAN',
#  'complaint_type': 'Panhandling',
#  'created_date': '2019-05-11T14:21:35.000',
#  'cross_street_1': 'PETER MINUIT PLACE',
#  'cross_street_2': 'SOUTH STREET',
#  'descriptor': 'N/A',
#  'due_date': '2019-05-11T22:21:35.000',
#  'facility_type': 'Precinct',
#  'incident_zip': '10004',
#  'landmark': 'SI FERRY TERMINAL',
#  'latitude': '40.70096726219546',
#  'location': {'type': 'Point',
#   'coordinates': [-74.013134888845, 40.700967262195]},
#  'location_type': 'Street/Sidewalk',
#  'longitude': '-74.01313488884514',
#  'open_data_channel_type': 'PHONE',
#  'park_borough': 'MANHATTAN',
#  'park_facility_name': 'Unspecified',
#  'resolution_action_updated_date': '2019-05-11T14:44:10.000',
#  'resolution_description': 'The Police Department responded and upon arrival those responsible for the condition were gone.',
#  'status': 'Closed',
#  'unique_key': '42649886',
#  'x_coordinate_state_plane': '980608',
#  'y_coordinate_state_plane': '194658'}

# %% [markdown]
# ## Create a Pandas DataFrame of the Data From the Response

# %%
# Formulation 1 
df_1 = pd.DataFrame(results)

print(len(df_1))
print(df_1.columns)
df_1.head()
# Out:
# 1000
# Index(['address_type', 'agency', 'agency_name', 'bbl', 'borough',
#        'bridge_highway_direction', 'bridge_highway_name',
#        'bridge_highway_segment', 'city', 'closed_date', 'community_board',
#        'complaint_type', 'created_date', 'cross_street_1', 'cross_street_2',
#        'descriptor', 'due_date', 'facility_type', 'incident_address',
#        'incident_zip', 'intersection_street_1', 'intersection_street_2',
#        'landmark', 'latitude', 'location', 'location_type', 'longitude',
#        'open_data_channel_type', 'park_borough', 'park_facility_name',
#        'resolution_action_updated_date', 'resolution_description', 'road_ramp',
#        'status', 'street_name', 'taxi_company_borough',
#        'taxi_pick_up_location', 'unique_key', 'x_coordinate_state_plane',
#        'y_coordinate_state_plane'],
#       dtype='object')
#   address_type agency                             agency_name         bbl  \
# 0    PLACENAME   NYPD         New York City Police Department         NaN
# 1          NaN    DPR      Department of Parks and Recreation         NaN
# 2    BLOCKFACE    DEP  Department of Environmental Protection         NaN
# 3      ADDRESS    DEP  Department of Environmental Protection  1000290047
# 4      ADDRESS    DCA          Department of Consumer Affairs         NaN
#
#      borough bridge_highway_direction bridge_highway_name  \
# 0  MANHATTAN                      NaN                 NaN
# 1  MANHATTAN                      NaN                 NaN
# 2  MANHATTAN                      NaN                 NaN
# 3  MANHATTAN                      NaN                 NaN
# 4  MANHATTAN                      NaN                 NaN
#
#   bridge_highway_segment      city              closed_date  ...  \
# 0                    NaN  NEW YORK  2019-05-11T14:44:10.000  ...
# 1                    NaN  NEW YORK                      NaN  ...
# 2                    NaN  NEW YORK                      NaN  ...
# 3                    NaN  NEW YORK                      NaN  ...
# 4                    NaN  NEW YORK                      NaN  ...
#
#   resolution_action_updated_date  \
# 0        2019-05-11T14:44:10.000
# 1                            NaN
# 2                            NaN
# 3                            NaN
# 4                            NaN
#
#                               resolution_description road_ramp  status  \
# 0  The Police Department responded and upon arriv...       NaN  Closed
# 1  The Department of Parks and Recreation usually...       NaN    Open
# 2                                                NaN       NaN    Open
# 3                                                NaN       NaN    Open
# 4  The Department of Consumer Affairs (DCA) usual...       NaN    Open
#
#             street_name taxi_company_borough taxi_pick_up_location unique_key  \
# 0                   NaN                  NaN                   NaN   42649886
# 1                   NaN                  NaN                   NaN   42649879
# 2          WATER STREET                  NaN                   NaN   42649485
# 3  SOUTH WILLIAM STREET                  NaN                   NaN   42645611
# 4    WHITEHALL TERMINAL                  NaN                   NaN   42646047
#
#   x_coordinate_state_plane y_coordinate_state_plane
# 0                   980608                   194658
# 1                      NaN                      NaN
# 2                   981220                   195439
# 3                   981305                   195971
# 4                   980608                   194658
#
# [5 rows x 40 columns]

# %%
# Formulation 2 
df_2 = pd.DataFrame(data)

print(len(df_2))
print(df_2.columns)
df_2.head()
# Out:
# 1000
# Index(['address_type', 'agency', 'agency_name', 'bbl', 'borough',
#        'bridge_highway_direction', 'bridge_highway_name',
#        'bridge_highway_segment', 'city', 'closed_date', 'community_board',
#        'complaint_type', 'created_date', 'cross_street_1', 'cross_street_2',
#        'descriptor', 'due_date', 'facility_type', 'incident_address',
#        'incident_zip', 'intersection_street_1', 'intersection_street_2',
#        'landmark', 'latitude', 'location', 'location_type', 'longitude',
#        'open_data_channel_type', 'park_borough', 'park_facility_name',
#        'resolution_action_updated_date', 'resolution_description', 'road_ramp',
#        'status', 'street_name', 'taxi_company_borough',
#        'taxi_pick_up_location', 'unique_key', 'x_coordinate_state_plane',
#        'y_coordinate_state_plane'],
#       dtype='object')
#   address_type agency                             agency_name         bbl  \
# 0    PLACENAME   NYPD         New York City Police Department         NaN
# 1          NaN    DPR      Department of Parks and Recreation         NaN
# 2    BLOCKFACE    DEP  Department of Environmental Protection         NaN
# 3      ADDRESS    DEP  Department of Environmental Protection  1000290047
# 4      ADDRESS    DCA          Department of Consumer Affairs         NaN
#
#      borough bridge_highway_direction bridge_highway_name  \
# 0  MANHATTAN                      NaN                 NaN
# 1  MANHATTAN                      NaN                 NaN
# 2  MANHATTAN                      NaN                 NaN
# 3  MANHATTAN                      NaN                 NaN
# 4  MANHATTAN                      NaN                 NaN
#
#   bridge_highway_segment      city              closed_date  ...  \
# 0                    NaN  NEW YORK  2019-05-11T14:44:10.000  ...
# 1                    NaN  NEW YORK                      NaN  ...
# 2                    NaN  NEW YORK                      NaN  ...
# 3                    NaN  NEW YORK                      NaN  ...
# 4                    NaN  NEW YORK                      NaN  ...
#
#   resolution_action_updated_date  \
# 0        2019-05-11T14:44:10.000
# 1                            NaN
# 2                            NaN
# 3                            NaN
# 4                            NaN
#
#                               resolution_description road_ramp  status  \
# 0  The Police Department responded and upon arriv...       NaN  Closed
# 1  The Department of Parks and Recreation usually...       NaN    Open
# 2                                                NaN       NaN    Open
# 3                                                NaN       NaN    Open
# 4  The Department of Consumer Affairs (DCA) usual...       NaN    Open
#
#             street_name taxi_company_borough taxi_pick_up_location unique_key  \
# 0                   NaN                  NaN                   NaN   42649886
# 1                   NaN                  NaN                   NaN   42649879
# 2          WATER STREET                  NaN                   NaN   42649485
# 3  SOUTH WILLIAM STREET                  NaN                   NaN   42645611
# 4    WHITEHALL TERMINAL                  NaN                   NaN   42646047
#
#   x_coordinate_state_plane y_coordinate_state_plane
# 0                   980608                   194658
# 1                      NaN                      NaN
# 2                   981220                   195439
# 3                   981305                   195971
# 4                   980608                   194658
#
# [5 rows x 40 columns]

# %% [markdown]
# ## Create a Histogram of the Complaint Types From Your Dataset

# %%
# !pip install matplotlib

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Your code here 
df_1.complaint_type.value_counts().plot(kind='barh', figsize=(8,12))

# %%
df_2.complaint_type.value_counts().plot(kind='barh', figsize=(8,12))
